# %% [markdown]
# <a href="https://colab.research.google.com/github/Sukruthr/Household-Appliances-Energy-Prediction/blob/main/Appliances_Energy_Prediction_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data-driven prediction of energy use of appliances**
#
# **The data set is at 10 min for about 4.5 months. The house temperature and humidity conditions were monitored with a ZigBee wireless sensor network. Each wireless node transmitted the temperature and humidity conditions around 3.3 min. Then, the wireless data was averaged for 10 minutes periods. The energy data was logged every 10 minutes with m-bus energy meters. Weather from the nearest airport weather station Chievres Airport, Belgium) was downloaded from a public data set from Reliable Prognosis (rp5.ru) and merged together with the experimental data sets using the date and time column. Two random variables have been included in the data set for testing the regression models and to filter out non-predictive attributes (parameters).**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings
from sklearn.decomposition import PCA, LatentDirichletAllocation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.neural_network import MLPRegressor
import xgboost as xgb
from sklearn import neighbors
from sklearn.svm import SVR
import time
from math import sqrt
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from tensorflow.keras import Sequential, layers, Input

# %%
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/AlmaBetter/Team Capstone Projects/Appliances Energy Prediction - Supervised ML (Classification)/data_application_energy.csv'
df = pd.read_csv(file_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
#  18  RH_8         19735 non-null  float64
#  19  T9           19735 non-null  float64
#  20  RH_9         19735 non-null  float64
#  21  T_out        19735 non-null  float64
#  22  Press_mm_hg  19735 non-null  float64
#  23  RH_out       19735 non-null  float64
#  24  Windspeed    19735 non-null  float64
#  25  Visibility   19735 non-null  float64
#  26  Tdewpoint    19735 non-null  float64
#  27  rv1          19735 non-null  float64
#  28  rv2          19735 non-null  float64
# dtypes: float64(26), int64(2), object(1)
# memory usage: 4.4+ MB

# %% [markdown]
# **Number of entries : 19735 <br> No of features : 27 ( 2 Random Variables included )<br> Target Variable : Appliances <br> All features are numerical. No categorical variables. There seems to be no null values in our data set.**

# %%
df.head()
# Out:
#                   date  Appliances  lights  ...  Tdewpoint        rv1        rv2
# 0  2016-01-11 17:00:00          60      30  ...        5.3  13.275433  13.275433
# 1  2016-01-11 17:10:00          60      30  ...        5.2  18.606195  18.606195
# 2  2016-01-11 17:20:00          50      30  ...        5.1  28.642668  28.642668
# 3  2016-01-11 17:30:00          50      40  ...        5.0  45.410389  45.410389
# 4  2016-01-11 17:40:00          60      40  ...        4.9  10.084097  10.084097
#
# [5 rows x 29 columns]

# %%
df.describe()
# Out:
#          Appliances        lights  ...           rv1           rv2
# count  19735.000000  19735.000000  ...  19735.000000  19735.000000
# mean      97.694958      3.801875  ...     24.988033     24.988033
# std      102.524891      7.935988  ...     14.496634     14.496634
# min       10.000000      0.000000  ...      0.005322      0.005322
# 25%       50.000000      0.000000  ...     12.497889     12.497889
# 50%       60.000000      0.000000  ...     24.897653     24.897653
# 75%      100.000000      0.000000  ...     37.583769     37.583769
# max     1080.000000     70.000000  ...     49.996530     49.996530
#
# [8 rows x 28 columns]

# %%
temp_dict = {
    'T1' : 'temp_kitchen', 'T2' : 'temp_living', 'T3' : 'temp_laundry', 
    'T4' : 'temp_office', 'T5' : 'temp_bath', 'T6' : 'temp_outside',
    'T7' : 'temp_iron', 'T8' : 'temp_teen', 'T9' : 'temp_parents', 'T_out' : 'temp_station'
}

# %%
energy_df = df.rename(columns=temp_dict)

# %%
humid_dict = {
    'RH_1' : 'humid_kitchen', 'RH_2' : 'humid_living', 'RH_3' : 'humid_laundry', 
    'RH_4' : 'humid_office', 'RH_5' : 'humid_bath', 'RH_6' : 'humid_outside',
    'RH_7' : 'humid_iron', 'RH_8' : 'humid_teen', 'RH_9' : 'humid_parents', 'RH_out' : 'humid_station'
}

# %%
energy_df = energy_df.rename(columns=humid_dict)

# %%
energy_df[temp_dict.values()].describe()
# Out:
#        temp_kitchen   temp_living  ...  temp_parents  temp_station
# count  19735.000000  19735.000000  ...  19735.000000  19735.000000
# mean      21.686571     20.341219  ...     19.485828      7.411665
# std        1.606066      2.192974  ...      2.014712      5.317409
# min       16.790000     16.100000  ...     14.890000     -5.000000
# 25%       20.760000     18.790000  ...     18.000000      3.666667
# 50%       21.600000     20.000000  ...     19.390000      6.916667
# 75%       22.600000     21.500000  ...     20.600000     10.408333
# max       26.260000     29.856667  ...     24.500000     26.100000
#
# [8 rows x 10 columns]

# %% [markdown]
# **OBSERVATIONS** : <br>
# 1. **Average outside temperature over a period of 4.5 months is around 7.5 degrees. It ranges from -6 - 28 degrees**
# 2. **While average temperature inside the building has been around 20 degrees for all the rooms. It ranges from 14 - 30 degrees**
# 3. **Which implies, Warming appliances have been used to keep the insides of the building warm. There must be some sort of direct correlation between temperature and consumption of energy inside house.**

# %%
energy_df[humid_dict.values()].describe()
# Out:
#        humid_kitchen  humid_living  ...  humid_parents  humid_station
# count   19735.000000  19735.000000  ...   19735.000000   19735.000000
# mean       40.259739     40.420420  ...      41.552401      79.750418
# std         3.979299      4.069813  ...       4.151497      14.901088
# min        27.023333     20.463333  ...      29.166667      24.000000
# 25%        37.333333     37.900000  ...      38.500000      70.333333
# 50%        39.656667     40.500000  ...      40.900000      83.666667
# 75%        43.066667     43.260000  ...      44.338095      91.666667
# max        63.360000     56.026667  ...      53.326667     100.000000
#
# [8 rows x 10 columns]

# %% [markdown]
# **OBSERVATIONS :**
# 1. **Average humidity outside the building has been higher than the average humidity inside.**
# 2. **Average humidity at the weather station is significantly higher compared to outside humidity near the building.**
# 3. **Average humidity in the bathroom is significantly higher compared to other rooms due to obvious reasons.**
# 4. **Kids and parent room show a comparatively higher average humidity as well signifying the fact that, inhabitants of this building spend most of their time in these buildings.**

# %%
weather_cols = list(set(energy_df.columns) - set(list(temp_dict.values())) - set(list(humid_dict.values())) - {'Appliances', 'lights', 'rv1', 'rv2'})
weather_cols
# Out:
# ['Windspeed', 'Visibility', 'date', 'Press_mm_hg', 'Tdewpoint']

# %% [markdown]
# **Distribution of our appliances energy usage :**

# %%
df.Appliances.describe()
# Out:
# count    19735.000000
# mean        97.694958
# std        102.524891
# min         10.000000
# 25%         50.000000
# 50%         60.000000
# 75%        100.000000
# max       1080.000000
# Name: Appliances, dtype: float64

# %%
sns.histplot(df['Appliances'],bins=50)

# %% [markdown]
# **75% of Appliance consumption is less than 100 Wh . With the maximum consumption of 1080 Wh , there will be outliers in this column and there are small number of cases where consumption is very high**

# %%
df.lights.hist(bins=10)

# %%
df.lights.value_counts()
# Out:
# 0     15252
# 10     2212
# 20     1624
# 30      559
# 40       77
# 50        9
# 60        1
# 70        1
# Name: lights, dtype: int64

# %% [markdown]
# **Since most of the value in lights column is 0, it wont be playing much role in our model. Hence we drop the lights feature from our dataframe.**

# %%
energy_df = energy_df.drop('lights', axis=1)

# %% [markdown]
# ### **Energy consumption**

# %% [markdown]
# **Energy Consumption pattern of the household at different times of the day over different time periods**

# %%
energy_df['weekday'] = ((pd.to_datetime(energy_df['date']).dt.dayofweek)// 5 == 0).astype(int)
energy_df['hour'] = pd.to_datetime(energy_df['date']).dt.hour
energy_df['month'] = pd.to_datetime(energy_df['date']).dt.month

# %%
fig, ax = plt.subplots(1,1,figsize=(7,5))
energy_df.groupby('hour').agg({'Appliances' : 'mean'}).plot.bar(ax=ax)
ax.set_ylabel('Appliance energy (Wh)')
# Out:
# Text(0, 0.5, 'Appliance energy (Wh)')

# %% [markdown]
# **Above figure is a representation of average energy consumption of appliances at different time of the day over a period of 4.5 months. We observe two peak hours. One at 11 am in the morning and other at 6 PM in the evening. While the peak at 11 am is shallow and low, peak at 6 PM is comparatively higher and sharper.**
#
# **We observe that over the sleeping hours (10 PM - 6 AM) the energy consumption of appliances is around 50 Wh. After about 6 AM, energy consumption starts to rise gradually up until 11 AM (probably due to morning chores). And then gradually decreases to around 100 Wh at about 3 PM. After which the energy consumption drastically shoots up up until 6 PM in the evening (probably due to requirement lights in rooms). However energy consumption of appliances reverts back to 50 Wh, as night approaches and people in the house go to bed at around 10 PM.**

# %%
fig, ax = plt.subplots(1,1,figsize=(20,5))
energy_df.groupby(['month','hour']).agg({'Appliances' : 'mean'}).plot.bar(ax=ax)
ax.set_ylabel('Appliance enrergy (Wh)')
# Out:
# Text(0, 0.5, 'Appliance enrergy (Wh)')

# %% [markdown]
# **A trend of high consumption hours for each month seems to be similar to the over all trend**

# %% [markdown]
# **What about weekdays and weekends?**

# %%
fig, ax = plt.subplots(1,2,figsize=(15,5))
week_df = energy_df.groupby(['weekday','hour']).agg({'Appliances':'mean'}).reset_index(0)
week_df[week_df.weekday==0].Appliances.plot.bar(ax=ax[0], label='weekends')
week_df[week_df.weekday==1].Appliances.plot.bar(ax=ax[1], label='weekdays')
ax[0].legend(loc='best')
ax[1].legend(loc='best')
ax[0].set_ylabel('Appliance Energy (Wh)')
ax[1].set_ylabel('Appliance Energy (Wh)')
# Out:
# Text(0, 0.5, 'Appliance Energy (Wh)')

# %% [markdown]
# **We observe that the energy consumption of appliances during the office hours (8 AM - 4 PM) is higher in weekends compared to the weekdays. Also, average overall consumption is higher in weekends is pretty high.**

# %% [markdown]
# **Lets look at how temperature and humidity levels vary inside different rooms !**

# %% [markdown]
# ### **Temperature levels**

# %%
fig, axes = plt.subplots(2,5,figsize=(50,20))
for i, temp in enumerate(temp_dict.values()):
  energy_df.groupby('hour').agg({temp : 'mean'}).plot.bar(ax=axes[i//5, i%5])
  axes[i//5, i%5].legend(loc='best')
  axes[i//5, i%5].set_title(temp)

# %% [markdown]
# **The average temperature inside each of the rooms has been almost constant over the day. However the average temperature outside the building and near the station changes over the course of the day. The average night time temperature is around 6 degree C, while average day time temperature varies over hours and peaks to 12 degree C at about 2-3 PM in the afternoon.**

# %%
fig, ax = plt.subplots(1,1,figsize=(20,5))
energy_df.groupby(['month','hour']).agg({'temp_outside' : 'mean'}).plot.bar(ax=ax)

# %%
fig, axes = plt.subplots(2,5,figsize=(50,20))
for i, temp in enumerate(temp_dict.values()):
  energy_df.groupby('month').agg({temp : 'mean'}).plot.bar(ax=axes[i//5, i%5])
  axes[i//5, i%5].legend(loc='best')
  axes[i//5, i%5].set_title(temp)

# %% [markdown]
# **We observe a significant increasing trend of daytime outside temperatures over the course of 5 months starting from an avg of 4 degree celsius in 1st month to an average of 15 degree celsius in month 5. The outside temperatures seem to have an impact over temperature inside too, although the variance of temperatures inside the building is low, since the temperature inside is controlled. Although the increase temperature seem to have no impact on the appliance consumtion patterns.**

# %% [markdown]
# ### **Humidity levels**

# %%
fig, axes = plt.subplots(2,5,figsize=(50,20))
for i, humid in enumerate(humid_dict.values()):
  energy_df.groupby('hour').agg({humid : 'mean'}).plot.bar(ax=axes[i//5, i%5])
  axes[i//5, i%5].legend(loc='best')
  axes[i//5, i%5].set_title(humid)

# %%
fig, ax = plt.subplots(1,1,figsize=(20,5))
energy_df.groupby(['month','hour']).agg({'humid_outside' : 'mean'}).plot.bar(ax=ax)

# %%
fig, axes = plt.subplots(2,5,figsize=(50,20))
for i, humid in enumerate(humid_dict.values()):
  energy_df.groupby('month').agg({humid : 'mean'}).plot.bar(ax=axes[i//5, i%5])
  axes[i//5, i%5].legend(loc='best')
  axes[i//5, i%5].set_title(humid)

# %% [markdown]
# **Although the humidity outside building tend to decrease over months, the humidity inside rooms seem to be unaffected. The humidity levels outside seem to be negatively correlated to with the temperature levels outside. Lets check !**

# %%
energy_df[['temp_outside', 'humid_outside']].corr()
# Out:
#                temp_outside  humid_outside
# temp_outside       1.000000      -0.672137
# humid_outside     -0.672137       1.000000

# %% [markdown]
# **Indeed there is a strong negative correlation between temperature and humidity levels outside. As temperature increases, moisture levels in the air decreases. We also observe that during the day time when the temperatures are high, humidity levels are low.**

# %% [markdown]
# **Lets look at correlation matrix of temperature and humidity levels**

# %%
cols = list(temp_dict.values())
cols.extend(list(humid_dict.values()))
cols.extend(['Appliances'])
fig, ax = plt.subplots(1,1,figsize=(15,15))
sns.heatmap(energy_df[cols].corr(), ax=ax, annot=True)

# %% [markdown]
# **OBSERVATIONS :**
#
# * **From the correlation graph we clearly observe that the features related to temperature and features related to humidity have positive correlation within themselves whereas have a a very little to no correlation with each other.**
# * **Humidity outside have a strong negative correlation with temperature levels as already discussed.**
# * **Apart from that we observe that a couple features such as humidity at station, temperature outside the building and temperature in the living room have a comparatively high absolute correlation (above 0.12) with Appliances energy consumption.**

# %%
# let us plot the variation of energy consumption with these variables
fig, axes = plt.subplots(4,5,figsize = (50,40))
for i, col in enumerate(cols[:-1]):
  ax = axes[i//5, i%5]
  ax.scatter(energy_df[col], energy_df['Appliances'])
  ax.set_xlabel(col)
  ax.set_ylabel('Appliances')

# %% [markdown]
# **Lets look at the dependence of appliance energy consumption on newly created variables !**

# %%
fig, ax = plt.subplots(1,1,figsize=(7,5))
sns.heatmap(energy_df[['month', 'weekday', 'hour', 'Appliances']].corr(), annot=True, ax=ax)

# %% [markdown]
# * **As we have observed earlier as well, there seenms to be no correlation between month and the observed energy use i.e. the enegy consumption pretty much remains similar over all months. Similarly there is no direct effect of weekdays on appliance energy consumption.**
# * **Although there is a correlation of 0.22 between hour and appliances**

# %%
def create_session(x):
  if x <= 6 or x >= 22:
    return 1
  elif x>6 and x <=15:
    return 2
  else:
    return 3

# %%
# lets create a new column based on our observations
energy_df['session'] = energy_df['hour'].apply(lambda x : create_session(x))

# %%
fig,ax = plt.subplots(1,1,figsize=(7,5))
sns.heatmap(energy_df[['session', 'Appliances']].corr(), ax = ax, annot=True)

# %%
fig, ax = plt.subplots(1,1,figsize=(7,5))
sns.boxplot(x='session',y='Appliances',data=energy_df, ax = ax)

# %% [markdown]
# **We were now able to increase the correlation to 0.34 by making creating this new row. We see a clear distinction of power consumtion in different sessions.**

# %% [markdown]
# **Lets look at features related to weather as well.**

# %%
fig,ax = plt.subplots(1,1,figsize=(20,15))
sns.heatmap(energy_df[weather_cols + cols].corr(), ax = ax, annot=True)

# %% [markdown]
# **Tdewpoint shows a high correlation with most of the tempearture and humidity level features than any other weather parameters. Pressure, windspeed and visibiltiy show little to no correlation. We might need to include these only these feaatures in our final model**

# %% [markdown]
# **Lets now deep dive into reducing the temperature and humidity parameters through some feature engineering and come up with features that explain maximum variability.**

# %%
temp_cols = list(set(list(temp_dict.values())) - {'temp_outside', 'temp_station'})
energy_df['mean_temp'] = energy_df[temp_cols].mean(axis=1)
energy_df[['mean_temp', 'Appliances']].corr()
# Out:
#             mean_temp  Appliances
# mean_temp     1.00000     0.05474
# Appliances    0.05474     1.00000

# %% [markdown]
# **Since most of the temperature variables inside the room show little to know correlation with target variable, lets try to find components that could explain maximum variance, which might improve the correlation with target variable as well.**

# %% [markdown]
# **Before doing PCA, I need to split the data into train and test, and fit PCA on train set**

# %% [markdown]
# ### **PCA on temperatures**

# %%
train_energy_df, test_energy_df = train_test_split(energy_df, test_size=0.2, random_state=1)

# %%
pca = PCA()
pca.fit(train_energy_df[temp_cols])
temp_pca = pca.transform(energy_df[temp_cols])
variance = pca.explained_variance_ratio_*100
fig, ax = plt.subplots(1,1,figsize=(7,5))
ax.bar(range(len(variance)), variance)
ax.plot(range(len(variance)), np.cumsum(variance),'r.-',linewidth=2, label='Cummulative variance %')
ax.set_xlabel('Principal components')
ax.set_ylabel('Explained variance %')
plt.legend(loc='best')

# %%
variance
# Out:
# array([84.42749838,  7.33014216,  2.3562388 ,  2.09550508,  1.47195967,
#         1.21891325,  0.69977714,  0.39996553])

# %% [markdown]
# First two components seem to explain more than 91 % of variance in data.

# %%
for i in range(temp_pca.shape[1]):
  energy_df[f'temp_pca{i+1}'] = temp_pca[:,i]

# %%
fig,ax = plt.subplots(1,1,figsize=(9,7))
sns.heatmap(energy_df[['temp_pca1', 'temp_pca2', 'temp_pca3', 'temp_pca4','temp_pca5', 'temp_pca6', 'temp_pca7', 'temp_pca8', 'Appliances']].corr(), ax = ax, annot=True)

# %%
fig, axes = plt.subplots(1,2,figsize=(13,5))
for i, j in enumerate((6,8)):
  axes[i].scatter(energy_df[f'temp_pca{j}'], energy_df['Appliances'])

# %%
#Lets look at components of humid_pca4
dict(zip(temp_cols, pca.components_[7,:]))
# Out:
# {'temp_bath': -0.21732855159144732,
#  'temp_iron': -0.24026540991588502,
#  'temp_kitchen': 0.62520209183931,
#  'temp_laundry': -0.2968959599105865,
#  'temp_living': -0.11736304703987917,
#  'temp_office': -0.09845473026092916,
#  'temp_parents': 0.6025874320322225,
#  'temp_teen': -0.1715719523850321}

# %% [markdown]
# ### **PCA on humidity**

# %%
humid_cols = list(set(list(humid_dict.values())) - {'humid_outside', 'humid_station'})
energy_df['mean_humid'] = energy_df[temp_cols].mean(axis=1)
energy_df[['mean_humid', 'Appliances']].corr()
# Out:
#             mean_humid  Appliances
# mean_humid     1.00000     0.05474
# Appliances     0.05474     1.00000

# %%
pca = PCA()
pca.fit(train_energy_df[humid_cols])
humid_pca = pca.transform(energy_df[humid_cols])
variance = pca.explained_variance_ratio_*100
fig, ax = plt.subplots(1,1,figsize=(7,5))
ax.bar(range(len(variance)), variance)
ax.plot(range(len(variance)), np.cumsum(variance),'r.-',linewidth=2, label='Cummulative variance %')
ax.set_xlabel('Principal components')
ax.set_ylabel('Explained variance %')
plt.legend(loc='best')

# %%
variance
# Out:
# array([62.09137315, 28.02035975,  3.84761759,  2.19313449,  1.40502588,
#         1.22143306,  0.64956943,  0.57148664])

# %%
for i in range(humid_pca.shape[1]):
  energy_df[f'humid_pca{i+1}'] = humid_pca[:,i]

# %%
fig,ax = plt.subplots(1,1,figsize=(7,5))
sns.heatmap(energy_df[['humid_pca1', 'humid_pca2', 'humid_pca3', 'humid_pca4', 'humid_pca6', 'humid_pca7', 'humid_pca8', 'Appliances']].corr(), ax = ax, annot=True)

# %%
plt.scatter(energy_df['humid_pca4'], energy_df['Appliances'])

# %%
#Lets look at components of humid_pca4
dict(zip(humid_cols, pca.components_[3,:]))
# Out:
# {'humid_bath': -0.005052352457213666,
#  'humid_iron': 0.07897694512980259,
#  'humid_kitchen': 0.412312228426888,
#  'humid_laundry': 0.29088037088150964,
#  'humid_living': -0.5395785231761474,
#  'humid_office': 0.4102126219725881,
#  'humid_parents': -0.01890427923705612,
#  'humid_teen': -0.5285334448509862}

# %%
energy_df['diff_temp'] = energy_df['temp_outside'] - energy_df['mean_temp']
energy_df[['diff_temp', 'Appliances']].corr()
# Out:
#             diff_temp  Appliances
# diff_temp     1.00000     0.12411
# Appliances    0.12411     1.00000

# %%
energy_df['log_Appliances'] = np.log(energy_df['Appliances'])
sns.histplot(energy_df.log_Appliances,bins=50)

# %% [markdown]
# # **Modeling with PCA features**

# %%
final_features = ['temp_pca1', 'temp_pca2', 'humid_pca1', 'humid_pca2', 'temp_outside', 'humid_outside', 'weekday', 'session', 'Windspeed', 'Press_mm_hg', 'Appliances']

# %%
fig,ax = plt.subplots(1,1,figsize=(7,5))
sns.heatmap(energy_df[final_features].corr(), ax = ax, annot=True)

# %%
final_train_df, final_test_df = train_test_split(energy_df[final_features], test_size = 0.2, random_state = 1)

# %%
X_train, y_train = final_train_df.drop('Appliances', axis=1), final_train_df['Appliances']
X_test, y_test = final_test_df.drop('Appliances', axis=1), final_test_df['Appliances']

# %%
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.values.reshape([-1,1])).flatten()
y_test = sc_y.transform(y_test.values.reshape([-1,1])).flatten()

# %% [markdown]
# **The ML regressor models that we use are :**
# * **Lasso Regressor**
# * **Ridge Regressor**
# * **KNeighbors Regressor**
# * **Support Vector Regressor**
# * **Random Forest Regressor**
# * **Extra Tree Regressor**
# * **Gradient Boosting Regressor**
# * **XGB Regressor**
# * **MLP Regressor**

# %%
models = [
           ['Lasso: ', Lasso()],
           ['Ridge: ', Ridge()],
           ['KNeighborsRegressor: ',  neighbors.KNeighborsRegressor()],
           ['SVR:' , SVR(kernel='rbf')],
           ['RandomForest ',RandomForestRegressor()],
           ['ExtraTreeRegressor :',ExtraTreesRegressor()],
           ['GradientBoostingRegressor: ', GradientBoostingRegressor()] ,
           ['XGBRegressor: ', xgb.XGBRegressor()] ,
           ['MLPRegressor: ', MLPRegressor(  activation='relu', solver='adam',learning_rate='adaptive',max_iter=1000,learning_rate_init=0.01,alpha=0.01)]
         ]

# %%
model_data = []
for name,curr_model in models :
    curr_model_data = {}
    curr_model.random_state = 78
    curr_model_data["Name"] = name
    start = time.time()
    curr_model.fit(X_train,y_train)
    end = time.time()
    curr_model_data["Train_Time"] = end - start
    curr_model_data["Train_R2_Score"] = r2_score(y_train,curr_model.predict(X_train))
    curr_model_data["Test_R2_Score"] = r2_score(y_test,curr_model.predict(X_test))
    curr_model_data["Test_RMSE_Score"] = np.sqrt(mean_squared_error(y_test,curr_model.predict(X_test)))
    model_data.append(curr_model_data)
# Out:
# [14:39:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
results_df = df = pd.DataFrame(model_data)

# %%
results_df
# Out:
#                           Name  Train_Time  ...  Test_R2_Score  Test_RMSE_Score
# 0                      Lasso:     0.006494  ...      -0.000777         1.028791
# 1                      Ridge:     0.006655  ...       0.124513         0.962240
# 2        KNeighborsRegressor:     0.055930  ...       0.473707         0.746057
# 3                         SVR:   12.788692  ...       0.142802         0.952136
# 4                RandomForest    13.969085  ...       0.559954         0.682193
# 5         ExtraTreeRegressor :    3.888462  ...       0.641419         0.615817
# 6  GradientBoostingRegressor:     4.197927  ...       0.217850         0.909501
# 7               XGBRegressor:     1.190389  ...       0.213623         0.911956
# 8               MLPRegressor:     6.496660  ...       0.260662         0.884260
#
# [9 rows x 5 columns]

# %%
results_df.plot.bar(x="Name", y=['Test_R2_Score' , 'Train_R2_Score' , 'Test_RMSE_Score'], title = 'Results' , width = .6, figsize= (20,8))

# %% [markdown]
# **OBSERVATIONS :**
#
# * **Extra Tree Regressor performs the best so far with a R2 score of 0.59 and RMSE of 0.65.**
# * **Lasso regression is the worst performing model so far.**

# %% [markdown]
# # **Hyper-parameter Tuning**

# %%
from sklearn.model_selection import GridSearchCV
param_grid = [{
              'max_depth': [80, 150, 200,250],
              'n_estimators' : [100,150,200,250],
              'max_features': ["auto", "sqrt", "log2"]
            }]
reg = ExtraTreesRegressor(random_state=40)
grid_search = GridSearchCV(estimator = reg, param_grid = param_grid, cv = 5, n_jobs = -1 , scoring='r2' , verbose=2)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(random_state=40), n_jobs=-1,
#              param_grid=[{'max_depth': [80, 150, 200, 250],
#                           'max_features': ['auto', 'sqrt', 'log2'],
#                           'n_estimators': [100, 150, 200, 250]}],
#              scoring='r2', verbose=2)

# %%
grid_search.best_params_
# Out:
# {'max_depth': 80, 'max_features': 'sqrt', 'n_estimators': 250}

# %%
grid_search.best_estimator_
# Out:
# ExtraTreesRegressor(max_depth=80, max_features='sqrt', n_estimators=250,
#                     random_state=40)

# %%
grid_search.best_estimator_.score(X_train,y_train)
# Out:
# 1.0

# %%
grid_search.best_estimator_.score(X_test,y_test)
# Out:
# 0.6420092203610108

# %%
np.sqrt(mean_squared_error(y_test, grid_search.best_estimator_.predict(X_test)))
# Out:
# 0.6153103158401956

# %% [markdown]
# **We observe a minute improvement in R2 score and RMSE score after hyper parameter tuning of Extra Trees Regressor.**

# %%
errors = []
errors.append(np.sqrt(mean_squared_error(y_test[y_test*sc_y.scale_ + sc_y.mean_ < 300]*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test[y_test*sc_y.scale_ + sc_y.mean_ < 300,:])*sc_y.scale_ + sc_y.mean_)))

# %%
errors.append(np.sqrt(mean_squared_error(y_test[y_test*sc_y.scale_ + sc_y.mean_ > 300]*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test[y_test*sc_y.scale_ + sc_y.mean_ > 300,:])*sc_y.scale_ + sc_y.mean_)))

# %%
plt.bar(x=['Below 300', 'Above 300'], height=errors, width = 0.5)
plt.axhline(np.sqrt(mean_squared_error(y_test*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test)*sc_y.scale_ + sc_y.mean_)), color='red', label='average RMSE')
plt.xlabel('Appliances Energy (Wh)')
plt.ylabel('RMSE')
plt.legend(loc='best')

# %% [markdown]
# **The model seems to make more errors in predicting the ones where actual energy consumption levels of appliances is quite high (above 300 Wh). While below 300 Wh, the RMSE is below the average RMS of entire test set.**

# %%
X_test = pd.DataFrame(X_test, columns=final_features[:-1])
y_test = pd.Series(y_test, name = 'Appliances')

# %%
session_errors = []
for i in range(1,4):
  session_errors.append(np.sqrt(mean_squared_error(y_test[X_test.session*sc_X.scale_[-3] + sc_X.mean_[-3] == i]*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test[X_test.session*sc_X.scale_[-3] + sc_X.mean_[-3] == i])*sc_y.scale_ + sc_y.mean_)))

# %%
plt.bar(x=['10 PM - 6 AM', '6 AM - 3 PM', '3 PM - 10 PM'], height=session_errors, width = 0.5)
plt.axhline(np.sqrt(mean_squared_error(y_test*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test)*sc_y.scale_ + sc_y.mean_)), color='red', label='average RMSE')
plt.xlabel('Appliances Energy (Wh)')
plt.ylabel('RMSE')
plt.legend(loc='best')

# %% [markdown]
# **When we look at the root mean squared errors made in prediction of energy consumption in appliances at different time of the day, we observe that errors made are quite less than the average RMSE of entire test set. Which is quite intuitive since we had little to no variance in energy consumption in those hours. However the errors are above average for other two time frames, where we had seen a quite a variance in energy levels.**

# %%
fig, axes = plt.subplots(1,1,figsize=(20,5))
plt.plot(range(len(y_test[:200])), y_test[:200]*sc_y.scale_ + sc_y.mean_, label='actual')
plt.plot(range(len(y_test[:200])), grid_search.best_estimator_.predict(X_test.iloc[:200,:])*sc_y.scale_ + sc_y.mean_, label='predicted')
plt.legend(loc='best')
plt.ylabel('Appliance energy consumption (Wh)')
plt.xlabel('Samples')
# Out:
# Text(0.5, 0, 'Samples')

# %%
feature_indices = np.argsort(grid_search.best_estimator_.feature_importances_)
importances = grid_search.best_estimator_.feature_importances_
indices = np.argsort(importances)[::-1]
names = [final_train_df.columns[i] for i in indices]

plt.figure(figsize=(10,6))
plt.title("Feature Importance")
plt.bar(range(X_train.shape[1]), importances[indices])
plt.xticks(range(X_train.shape[1]), names, rotation=90)
plt.show()

# %% [markdown]
# **Looking at the feature importances, it is clear that the PCA features of temperature and humidity hold slightly higher feature importances compared to others. However almost all the features used for modelling hold equal importance**

# %% [markdown]
# # **Modeling Without PCA features**

# %% [markdown]
# **Including all temperature and humidity features and engineered feature 'session' in our features set.**

# %%
final_features = ['temp_laundry','temp_bath', 'temp_kitchen', 'temp_parents', 'temp_office', 'temp_living', 'temp_teen', 'temp_iron','humid_kitchen',
 'humid_office', 'humid_bath', 'humid_living', 'humid_parents', 'humid_laundry', 'humid_teen', 'humid_iron',
  'temp_outside', 'humid_outside', 'temp_station', 'humid_station', 'weekday', 'session', 'Windspeed', 'Press_mm_hg', 'Appliances']

# %%
final_train_df, final_test_df = train_test_split(energy_df[final_features], test_size = 0.2, random_state = 1)

# %%
X_train, y_train = final_train_df.drop('Appliances', axis=1), final_train_df['Appliances']
X_test, y_test = final_test_df.drop('Appliances', axis=1), final_test_df['Appliances']

# %%
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.values.reshape([-1,1])).flatten()
y_test = sc_y.transform(y_test.values.reshape([-1,1])).flatten()

# %%
models = [
           ['Lasso: ', Lasso()],
           ['Ridge: ', Ridge()],
           ['KNeighborsRegressor: ',  neighbors.KNeighborsRegressor()],
           ['SVR:' , SVR(kernel='rbf')],
           ['RandomForest ',RandomForestRegressor()],
           ['ExtraTreeRegressor :',ExtraTreesRegressor()],
           ['GradientBoostingRegressor: ', GradientBoostingRegressor()],
           ['XGBRegressor: ', xgb.XGBRegressor()],
           ['MLPRegressor: ', MLPRegressor(  activation='relu', solver='adam',learning_rate='adaptive',max_iter=1000,learning_rate_init=0.01,alpha=0.01)]
         ]

# %%
model_data = []
for name,curr_model in models :
    curr_model_data = {}
    curr_model.random_state = 78
    curr_model_data["Name"] = name
    start = time.time()
    curr_model.fit(X_train,y_train)
    end = time.time()
    curr_model_data["Train_Time"] = end - start
    curr_model_data["Train_R2_Score"] = r2_score(y_train,curr_model.predict(X_train))
    curr_model_data["Test_R2_Score"] = r2_score(y_test,curr_model.predict(X_test))
    curr_model_data["Test_RMSE_Score"] = np.sqrt(mean_squared_error(y_test,curr_model.predict(X_test)))
    model_data.append(curr_model_data)
# Out:
# [14:52:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
results_df = pd.DataFrame(model_data)

# %%
results_df
# Out:
#                           Name  Train_Time  ...  Test_R2_Score  Test_RMSE_Score
# 0                      Lasso:     0.007046  ...      -0.000777         1.028791
# 1                      Ridge:     0.008931  ...       0.185596         0.928064
# 2        KNeighborsRegressor:     0.002160  ...       0.485173         0.737886
# 3                         SVR:   13.513763  ...       0.242499         0.895055
# 4                RandomForest    34.017598  ...       0.593457         0.655709
# 5         ExtraTreeRegressor :    8.579046  ...       0.644521         0.613148
# 6  GradientBoostingRegressor:     7.928089  ...       0.271252         0.877904
# 7               XGBRegressor:     1.751972  ...       0.271605         0.877691
# 8               MLPRegressor:    10.155653  ...       0.397394         0.798316
#
# [9 rows x 5 columns]

# %%
results_df.plot.bar(x="Name", y=['Test_R2_Score' , 'Train_R2_Score' , 'Test_RMSE_Score'], title = 'Results' , width = .6, figsize= (20,8))

# %% [markdown]
# **The model results are almost similar to that observed in models trained with PCA feature set.**

# %% [markdown]
# # **Hyper-parameter Tuning**

# %%
param_grid = [{
              'max_depth': [80, 150, 200,250],
              'n_estimators' : [100,150,200,250],
              'max_features': ["auto", "sqrt", "log2"]
            }]
reg = ExtraTreesRegressor(random_state=40)
grid_search = GridSearchCV(estimator = reg, param_grid = param_grid, cv = 5, n_jobs = -1 , scoring='r2' , verbose=2)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(random_state=40), n_jobs=-1,
#              param_grid=[{'max_depth': [80, 150, 200, 250],
#                           'max_features': ['auto', 'sqrt', 'log2'],
#                           'n_estimators': [100, 150, 200, 250]}],
#              scoring='r2', verbose=2)

# %%
grid_search.best_params_
# Out:
# {'max_depth': 80, 'max_features': 'sqrt', 'n_estimators': 200}

# %%
grid_search.best_estimator_
# Out:
# ExtraTreesRegressor(max_depth=80, max_features='sqrt', n_estimators=200,
#                     random_state=40)

# %%
grid_search.best_estimator_.score(X_train,y_train)
# Out:
# 1.0

# %%
grid_search.best_estimator_.score(X_test,y_test)
# Out:
# 0.6453971723995422

# %%
np.sqrt(mean_squared_error(y_test, grid_search.best_estimator_.predict(X_test)))
# Out:
# 0.6123918084485078

# %%
errors = []
errors.append(np.sqrt(mean_squared_error(y_test[y_test*sc_y.scale_ + sc_y.mean_ < 300]*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test[y_test*sc_y.scale_ + sc_y.mean_ < 300,:])*sc_y.scale_ + sc_y.mean_)))

# %%
errors.append(np.sqrt(mean_squared_error(y_test[y_test*sc_y.scale_ + sc_y.mean_ > 300]*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test[y_test*sc_y.scale_ + sc_y.mean_ > 300,:])*sc_y.scale_ + sc_y.mean_)))

# %%
plt.bar(x=['Below 300', 'Above 300'], height=errors, width = 0.5)
plt.axhline(np.sqrt(mean_squared_error(y_test*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test)*sc_y.scale_ + sc_y.mean_)), color='red', label='average RMSE')
plt.xlabel('Appliances Energy (Wh)')
plt.ylabel('RMSE')
plt.legend(loc='best')

# %% [markdown]
# **The model seems to make more errors in predicting the ones where actual energy consumption levels of appliances is quite high (above 300 Wh). While below 300 Wh, the RMSE is below the average RMS of entire test set.**

# %%
X_test = pd.DataFrame(X_test, columns=final_features[:-1])
y_test = pd.Series(y_test, name = 'Appliances')

# %%
session_errors = []
for i in range(1,4):
  session_errors.append(np.sqrt(mean_squared_error(y_test[X_test.session*sc_X.scale_[-3] + sc_X.mean_[-3] == i]*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test[X_test.session*sc_X.scale_[-3] + sc_X.mean_[-3] == i])*sc_y.scale_ + sc_y.mean_)))

# %%
plt.bar(x=['10 PM - 6 AM', '6 AM - 3 PM', '3 PM - 10 PM'], height=session_errors, width = 0.5)
plt.axhline(np.sqrt(mean_squared_error(y_test*sc_y.scale_ + sc_y.mean_, grid_search.best_estimator_.predict(X_test)*sc_y.scale_ + sc_y.mean_)), color='red', label='average RMSE')
plt.xlabel('Session (Time of the day)')
plt.ylabel('RMSE')
plt.legend(loc='best')

# %% [markdown]
# **When we look at the root mean squared errors made in prediction of energy consumption in appliances at different time of the day, we observe that errors made are quite less than the average RMSE of entire test set. Which is quite intuitive since we had little to no variance in energy consumption in those hours. However the errors are above average for other two time frames, where we had seen a quite a variance in energy levels.**

# %%
fig, axes = plt.subplots(1,1,figsize=(20,5))
plt.plot(range(len(y_test[:200])), y_test[:200]*sc_y.scale_ + sc_y.mean_, label='actual',linewidth=2)
plt.plot(range(len(y_test[:200])), grid_search.best_estimator_.predict(X_test.iloc[:200,:])*sc_y.scale_ + sc_y.mean_, label='predicted',linewidth=2)
plt.legend(loc='best')
plt.ylabel('Appliance energy consumption (Wh)')
plt.xlabel('Samples')
# Out:
# Text(0.5, 0, 'Samples')

# %% [markdown]
# **The above figure represents actual and predicted values of 200 samples in test set.**

# %%
feature_indices = np.argsort(grid_search.best_estimator_.feature_importances_)
importances = grid_search.best_estimator_.feature_importances_
indices = np.argsort(importances)[::-1]
names = [final_train_df.columns[i] for i in indices]

plt.figure(figsize=(10,6))
plt.title("Feature Importance")
plt.bar(range(X_train.shape[1]), importances[indices])
plt.xticks(range(X_train.shape[1]), names, rotation=90)
plt.show()

# %% [markdown]
# **In the case where we don't include any PCA features, the engineered feature 'session' seems to hold most importance among all the features.**

# %% [markdown]
# # **Neural Networks**

# %%
final_features = ['temp_pca1', 'temp_pca2', 'humid_pca1', 'humid_pca2', 'temp_outside', 'humid_outside', 'session', 'Windspeed', 'Press_mm_hg', 'weekday', 'Appliances']

# %%
final_train_df, final_test_df = train_test_split(energy_df[final_features], test_size = 0.2, random_state = 1)

# %%
X_train, y_train = final_train_df.drop('Appliances', axis=1), final_train_df['Appliances']
X_test, y_test = final_test_df.drop('Appliances', axis=1), final_test_df['Appliances']

# %%
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.values.reshape([-1,1])).flatten()
y_test = sc_y.transform(y_test.values.reshape([-1,1])).flatten()

# %%
def R_squared(y_true, y_pred):
  unexplained_error = tf.reduce_sum(tf.square(y_true - y_pred))
  total_error = tf.reduce_sum(tf.square(y_true - tf.reduce_mean(y_true, axis=0)))
  R2 = 1. - tf.truediv(unexplained_error, total_error)
  return R2

# %%
NN_model = Sequential([
                    Input((None,X_train.shape[1])),
                    layers.Dense(32,activation='relu',kernel_initializer='normal'),
                    layers.Dense(64,activation='relu', kernel_initializer='normal'),
                    layers.Dense(64,activation='relu', kernel_initializer='normal'),
                    layers.Dense(1,kernel_initializer='normal',activation='linear'),
])
NN_model.compile(loss='mean_squared_error', optimizer='adam', metrics=[R_squared])
NN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, None, 32)          352
#
#  dense_1 (Dense)             (None, None, 64)          2112
#
#  dense_2 (Dense)             (None, None, 64)          4160
#
#  dense_3 (Dense)             (None, None, 1)           65
#
# =================================================================
# Total params: 6,689
# Trainable params: 6,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf

# %%
NN_model.fit(X_train, y_train, epochs=500, validation_data=(X_test, y_test), workers=-1)
# Out:
# Epoch 1/500
# WARNING:tensorflow:Model was constructed with shape (None, None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 10), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 10).
# WARNING:tensorflow:Model was constructed with shape (None, None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 10), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 10).
# 493/494 [============================>.] - ETA: 0s - loss: 0.8776 - R_squared: 0.0485WARNING:tensorflow:Model was constructed with shape (None, None, 10) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 10), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 10).
# 494/494 [==============================] - 2s 3ms/step - loss: 0.8771 - R_squared: 0.0458 - val_loss: 0.8979 - val_R_squared: 0.1076
# Epoch 2/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.8353 - R_squared: 0.0706 - val_loss: 0.8873 - val_R_squared: 0.0997
# Epoch 3/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.8139 - R_squared: 0.0743 - val_loss: 0.8806 - val_R_squared: 0.0761
# Epoch 4/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.7996 - R_squared: 0.0300 - val_loss: 0.8507 - val_R_squared: 0.1737
# Epoch 5/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.7791 - R_squared: 0.0899 - val_loss: 0.8302 - val_R_squared: 0.1699
# Epoch 6/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.7587 - R_squared: 0.1008 - val_loss: 0.8056 - val_R_squared: 0.2046
# Epoch 7/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.7396 - R_squared: 0.1866 - val_loss: 0.7805 - val_R_squared: 0.1916
# Epoch 8/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.7263 - R_squared: 0.1668 - val_loss: 0.8005 - val_R_squared: 0.1923
# Epoch 9/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.7187 - R_squared: 0.1547 - val_loss: 0.7619 - val_R_squared: 0.2413
# Epoch 10/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.7026 - R_squared: 0.1423 - val_loss: 0.7561 - val_R_squared: 0.2255
# Epoch 11/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6953 - R_squared: 0.1789 - val_loss: 0.7540 - val_R_squared: 0.2478
# Epoch 12/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6907 - R_squared: 0.1724 - val_loss: 0.7550 - val_R_squared: 0.1973
# Epoch 13/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6810 - R_squared: 0.1829 - val_loss: 0.7759 - val_R_squared: 0.1727
# Epoch 14/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6675 - R_squared: 0.2257 - val_loss: 0.7673 - val_R_squared: 0.1304
# Epoch 15/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6596 - R_squared: 0.2274 - val_loss: 0.7288 - val_R_squared: 0.2160
# Epoch 16/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6571 - R_squared: 0.2098 - val_loss: 0.7838 - val_R_squared: 0.0381
# Epoch 17/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6474 - R_squared: 0.2566 - val_loss: 0.7323 - val_R_squared: 0.2385
# Epoch 18/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.6406 - R_squared: 0.2445 - val_loss: 0.6969 - val_R_squared: 0.2338
# Epoch 19/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.6338 - R_squared: 0.2145 - val_loss: 0.6964 - val_R_squared: 0.2609
# Epoch 20/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6291 - R_squared: 0.2456 - val_loss: 0.7156 - val_R_squared: 0.2377
# Epoch 21/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6244 - R_squared: 0.2799 - val_loss: 0.7103 - val_R_squared: 0.2376
# Epoch 22/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6193 - R_squared: 0.2590 - val_loss: 0.6879 - val_R_squared: 0.2463
# Epoch 23/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6151 - R_squared: 0.2786 - val_loss: 0.6897 - val_R_squared: 0.2385
# Epoch 24/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6150 - R_squared: 0.2649 - val_loss: 0.7052 - val_R_squared: 0.2741
# Epoch 25/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6025 - R_squared: 0.2416 - val_loss: 0.7044 - val_R_squared: 0.2595
# Epoch 26/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6027 - R_squared: 0.2687 - val_loss: 0.7025 - val_R_squared: 0.2958
# Epoch 27/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.6012 - R_squared: 0.2781 - val_loss: 0.6759 - val_R_squared: 0.2804
# Epoch 28/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5919 - R_squared: 0.2365 - val_loss: 0.6699 - val_R_squared: 0.2426
# Epoch 29/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5862 - R_squared: 0.3187 - val_loss: 0.6768 - val_R_squared: 0.3043
# Epoch 30/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5833 - R_squared: 0.2910 - val_loss: 0.6797 - val_R_squared: 0.2328
# Epoch 31/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.5812 - R_squared: 0.2702 - val_loss: 0.7036 - val_R_squared: 0.2406
# Epoch 32/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5768 - R_squared: 0.3104 - val_loss: 0.6937 - val_R_squared: 0.1722
# Epoch 33/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5716 - R_squared: 0.3168 - val_loss: 0.6861 - val_R_squared: 0.2386
# Epoch 34/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5692 - R_squared: 0.3088 - val_loss: 0.6624 - val_R_squared: 0.2836
# Epoch 35/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5607 - R_squared: 0.2865 - val_loss: 0.6779 - val_R_squared: 0.2994
# Epoch 36/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5593 - R_squared: 0.2961 - val_loss: 0.6479 - val_R_squared: 0.2671
# Epoch 37/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5557 - R_squared: 0.3102 - val_loss: 0.6723 - val_R_squared: 0.2755
# Epoch 38/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5543 - R_squared: 0.3082 - val_loss: 0.6517 - val_R_squared: 0.2668
# Epoch 39/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5494 - R_squared: 0.3394 - val_loss: 0.6598 - val_R_squared: 0.2736
# Epoch 40/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5506 - R_squared: 0.3157 - val_loss: 0.6523 - val_R_squared: 0.2772
# Epoch 41/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5485 - R_squared: 0.3222 - val_loss: 0.6501 - val_R_squared: 0.3219
# Epoch 42/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5410 - R_squared: 0.3482 - val_loss: 0.6527 - val_R_squared: 0.2973
# Epoch 43/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5352 - R_squared: 0.3201 - val_loss: 0.6558 - val_R_squared: 0.2724
# Epoch 44/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5335 - R_squared: 0.3241 - val_loss: 0.6501 - val_R_squared: 0.2956
# Epoch 45/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5296 - R_squared: 0.3525 - val_loss: 0.6617 - val_R_squared: 0.3079
# Epoch 46/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5340 - R_squared: 0.3331 - val_loss: 0.6838 - val_R_squared: 0.2438
# Epoch 47/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5269 - R_squared: 0.3360 - val_loss: 0.6539 - val_R_squared: 0.2532
# Epoch 48/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5258 - R_squared: 0.3441 - val_loss: 0.6261 - val_R_squared: 0.2821
# Epoch 49/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5270 - R_squared: 0.3478 - val_loss: 0.6613 - val_R_squared: 0.2316
# Epoch 50/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5177 - R_squared: 0.3527 - val_loss: 0.6778 - val_R_squared: 0.1605
# Epoch 51/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5202 - R_squared: 0.3485 - val_loss: 0.6408 - val_R_squared: 0.2861
# Epoch 52/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5149 - R_squared: 0.3664 - val_loss: 0.6266 - val_R_squared: 0.2950
# Epoch 53/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5116 - R_squared: 0.3800 - val_loss: 0.6557 - val_R_squared: 0.2036
# Epoch 54/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5118 - R_squared: 0.3853 - val_loss: 0.6436 - val_R_squared: 0.2382
# Epoch 55/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5026 - R_squared: 0.3771 - val_loss: 0.6277 - val_R_squared: 0.2719
# Epoch 56/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5049 - R_squared: 0.3571 - val_loss: 0.6386 - val_R_squared: 0.2553
# Epoch 57/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5062 - R_squared: 0.3911 - val_loss: 0.6667 - val_R_squared: 0.1520
# Epoch 58/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4948 - R_squared: 0.3670 - val_loss: 0.6240 - val_R_squared: 0.3184
# Epoch 59/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.5027 - R_squared: 0.3655 - val_loss: 0.6476 - val_R_squared: 0.2869
# Epoch 60/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4944 - R_squared: 0.3855 - val_loss: 0.6399 - val_R_squared: 0.2439
# Epoch 61/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4914 - R_squared: 0.3939 - val_loss: 0.6352 - val_R_squared: 0.2709
# Epoch 62/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4873 - R_squared: 0.3539 - val_loss: 0.6318 - val_R_squared: 0.2936
# Epoch 63/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4821 - R_squared: 0.3850 - val_loss: 0.6095 - val_R_squared: 0.3190
# Epoch 64/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4843 - R_squared: 0.3621 - val_loss: 0.6250 - val_R_squared: 0.2857
# Epoch 65/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4841 - R_squared: 0.3565 - val_loss: 0.6260 - val_R_squared: 0.2796
# Epoch 66/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4813 - R_squared: 0.4006 - val_loss: 0.6216 - val_R_squared: 0.3510
# Epoch 67/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4785 - R_squared: 0.3933 - val_loss: 0.6145 - val_R_squared: 0.3069
# Epoch 68/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4764 - R_squared: 0.3954 - val_loss: 0.6505 - val_R_squared: 0.1988
# Epoch 69/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4709 - R_squared: 0.3831 - val_loss: 0.6067 - val_R_squared: 0.3169
# Epoch 70/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4654 - R_squared: 0.4136 - val_loss: 0.6373 - val_R_squared: 0.2532
# Epoch 71/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4725 - R_squared: 0.4004 - val_loss: 0.6864 - val_R_squared: 0.1200
# Epoch 72/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4740 - R_squared: 0.3750 - val_loss: 0.6252 - val_R_squared: 0.3129
# Epoch 73/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4690 - R_squared: 0.4096 - val_loss: 0.6420 - val_R_squared: 0.2156
# Epoch 74/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4647 - R_squared: 0.4202 - val_loss: 0.6384 - val_R_squared: 0.2210
# Epoch 75/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4642 - R_squared: 0.4149 - val_loss: 0.6336 - val_R_squared: 0.2276
# Epoch 76/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4590 - R_squared: 0.3951 - val_loss: 0.6296 - val_R_squared: 0.2621
# Epoch 77/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4602 - R_squared: 0.3963 - val_loss: 0.6085 - val_R_squared: 0.2770
# Epoch 78/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4543 - R_squared: 0.3970 - val_loss: 0.6248 - val_R_squared: 0.2965
# Epoch 79/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4649 - R_squared: 0.4104 - val_loss: 0.5928 - val_R_squared: 0.3307
# Epoch 80/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4537 - R_squared: 0.4068 - val_loss: 0.6019 - val_R_squared: 0.3247
# Epoch 81/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4489 - R_squared: 0.4356 - val_loss: 0.6184 - val_R_squared: 0.2897
# Epoch 82/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4512 - R_squared: 0.4220 - val_loss: 0.6140 - val_R_squared: 0.2717
# Epoch 83/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4577 - R_squared: 0.3671 - val_loss: 0.5836 - val_R_squared: 0.3424
# Epoch 84/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4409 - R_squared: 0.3843 - val_loss: 0.6221 - val_R_squared: 0.2926
# Epoch 85/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4454 - R_squared: 0.4494 - val_loss: 0.5923 - val_R_squared: 0.3342
# Epoch 86/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4377 - R_squared: 0.4656 - val_loss: 0.6039 - val_R_squared: 0.3311
# Epoch 87/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4449 - R_squared: 0.4177 - val_loss: 0.6033 - val_R_squared: 0.2788
# Epoch 88/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4408 - R_squared: 0.4283 - val_loss: 0.6093 - val_R_squared: 0.2820
# Epoch 89/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4431 - R_squared: 0.4160 - val_loss: 0.6079 - val_R_squared: 0.2833
# Epoch 90/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4367 - R_squared: 0.4363 - val_loss: 0.5914 - val_R_squared: 0.3267
# Epoch 91/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4335 - R_squared: 0.4631 - val_loss: 0.5934 - val_R_squared: 0.3454
# Epoch 92/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4328 - R_squared: 0.4317 - val_loss: 0.6186 - val_R_squared: 0.2776
# Epoch 93/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4370 - R_squared: 0.4114 - val_loss: 0.6174 - val_R_squared: 0.2985
# Epoch 94/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4300 - R_squared: 0.4511 - val_loss: 0.5936 - val_R_squared: 0.2833
# Epoch 95/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4346 - R_squared: 0.4256 - val_loss: 0.6165 - val_R_squared: 0.3016
# Epoch 96/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4187 - R_squared: 0.4458 - val_loss: 0.6339 - val_R_squared: 0.1885
# Epoch 97/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4317 - R_squared: 0.4574 - val_loss: 0.6220 - val_R_squared: 0.2953
# Epoch 98/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4314 - R_squared: 0.4218 - val_loss: 0.5793 - val_R_squared: 0.3423
# Epoch 99/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4219 - R_squared: 0.4461 - val_loss: 0.6099 - val_R_squared: 0.3365
# Epoch 100/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4233 - R_squared: 0.4557 - val_loss: 0.6057 - val_R_squared: 0.3020
# Epoch 101/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4238 - R_squared: 0.4704 - val_loss: 0.5867 - val_R_squared: 0.3286
# Epoch 102/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4229 - R_squared: 0.4500 - val_loss: 0.6155 - val_R_squared: 0.2687
# Epoch 103/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4269 - R_squared: 0.4649 - val_loss: 0.5978 - val_R_squared: 0.3003
# Epoch 104/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4215 - R_squared: 0.4450 - val_loss: 0.6058 - val_R_squared: 0.2874
# Epoch 105/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4244 - R_squared: 0.4563 - val_loss: 0.6084 - val_R_squared: 0.3190
# Epoch 106/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4180 - R_squared: 0.4321 - val_loss: 0.5965 - val_R_squared: 0.3009
# Epoch 107/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4184 - R_squared: 0.4525 - val_loss: 0.6112 - val_R_squared: 0.2265
# Epoch 108/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4151 - R_squared: 0.4815 - val_loss: 0.5838 - val_R_squared: 0.3300
# Epoch 109/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.4111 - R_squared: 0.4844 - val_loss: 0.5797 - val_R_squared: 0.3045
# Epoch 110/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4143 - R_squared: 0.4492 - val_loss: 0.6010 - val_R_squared: 0.3262
# Epoch 111/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4003 - R_squared: 0.4567 - val_loss: 0.5825 - val_R_squared: 0.3222
# Epoch 112/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4115 - R_squared: 0.4662 - val_loss: 0.5948 - val_R_squared: 0.2910
# Epoch 113/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4028 - R_squared: 0.4721 - val_loss: 0.5811 - val_R_squared: 0.3265
# Epoch 114/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.4044 - R_squared: 0.4542 - val_loss: 0.6271 - val_R_squared: 0.2611
# Epoch 115/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4084 - R_squared: 0.4667 - val_loss: 0.5690 - val_R_squared: 0.3715
# Epoch 116/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4034 - R_squared: 0.4781 - val_loss: 0.6090 - val_R_squared: 0.2849
# Epoch 117/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4057 - R_squared: 0.4554 - val_loss: 0.6098 - val_R_squared: 0.2991
# Epoch 118/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4013 - R_squared: 0.4439 - val_loss: 0.5650 - val_R_squared: 0.3811
# Epoch 119/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4018 - R_squared: 0.4670 - val_loss: 0.5665 - val_R_squared: 0.3206
# Epoch 120/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4074 - R_squared: 0.4821 - val_loss: 0.5974 - val_R_squared: 0.2931
# Epoch 121/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3932 - R_squared: 0.4933 - val_loss: 0.5805 - val_R_squared: 0.2914
# Epoch 122/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3990 - R_squared: 0.4472 - val_loss: 0.5902 - val_R_squared: 0.3177
# Epoch 123/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3990 - R_squared: 0.5052 - val_loss: 0.5946 - val_R_squared: 0.2962
# Epoch 124/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.4001 - R_squared: 0.4746 - val_loss: 0.5730 - val_R_squared: 0.3562
# Epoch 125/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3933 - R_squared: 0.4786 - val_loss: 0.6161 - val_R_squared: 0.2170
# Epoch 126/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3974 - R_squared: 0.4374 - val_loss: 0.5679 - val_R_squared: 0.3644
# Epoch 127/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3829 - R_squared: 0.4770 - val_loss: 0.5848 - val_R_squared: 0.3054
# Epoch 128/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3907 - R_squared: 0.4685 - val_loss: 0.5784 - val_R_squared: 0.3172
# Epoch 129/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3865 - R_squared: 0.4916 - val_loss: 0.5829 - val_R_squared: 0.3194
# Epoch 130/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3887 - R_squared: 0.4776 - val_loss: 0.5893 - val_R_squared: 0.3098
# Epoch 131/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3901 - R_squared: 0.4675 - val_loss: 0.5599 - val_R_squared: 0.3289
# Epoch 132/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3828 - R_squared: 0.5007 - val_loss: 0.6194 - val_R_squared: 0.2017
# Epoch 133/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3900 - R_squared: 0.4709 - val_loss: 0.6065 - val_R_squared: 0.3023
# Epoch 134/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3856 - R_squared: 0.4969 - val_loss: 0.5881 - val_R_squared: 0.3053
# Epoch 135/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3809 - R_squared: 0.4932 - val_loss: 0.5811 - val_R_squared: 0.3171
# Epoch 136/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3896 - R_squared: 0.4887 - val_loss: 0.5911 - val_R_squared: 0.2953
# Epoch 137/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3762 - R_squared: 0.5047 - val_loss: 0.5956 - val_R_squared: 0.3030
# Epoch 138/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3814 - R_squared: 0.4876 - val_loss: 0.5708 - val_R_squared: 0.3474
# Epoch 139/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3873 - R_squared: 0.4906 - val_loss: 0.5702 - val_R_squared: 0.3392
# Epoch 140/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3760 - R_squared: 0.5224 - val_loss: 0.5826 - val_R_squared: 0.2959
# Epoch 141/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3785 - R_squared: 0.5179 - val_loss: 0.5953 - val_R_squared: 0.2564
# Epoch 142/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3795 - R_squared: 0.4974 - val_loss: 0.5707 - val_R_squared: 0.3433
# Epoch 143/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3700 - R_squared: 0.5140 - val_loss: 0.5787 - val_R_squared: 0.3239
# Epoch 144/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3704 - R_squared: 0.5233 - val_loss: 0.5800 - val_R_squared: 0.3172
# Epoch 145/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3789 - R_squared: 0.4723 - val_loss: 0.5917 - val_R_squared: 0.2688
# Epoch 146/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3712 - R_squared: 0.4900 - val_loss: 0.5758 - val_R_squared: 0.3181
# Epoch 147/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3765 - R_squared: 0.5108 - val_loss: 0.5992 - val_R_squared: 0.2876
# Epoch 148/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3747 - R_squared: 0.4790 - val_loss: 0.5821 - val_R_squared: 0.3448
# Epoch 149/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3685 - R_squared: 0.5004 - val_loss: 0.5608 - val_R_squared: 0.3539
# Epoch 150/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3636 - R_squared: 0.4945 - val_loss: 0.6087 - val_R_squared: 0.2292
# Epoch 151/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3737 - R_squared: 0.4932 - val_loss: 0.5518 - val_R_squared: 0.3784
# Epoch 152/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3601 - R_squared: 0.5238 - val_loss: 0.5785 - val_R_squared: 0.3231
# Epoch 153/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3631 - R_squared: 0.5121 - val_loss: 0.5766 - val_R_squared: 0.3297
# Epoch 154/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3669 - R_squared: 0.5069 - val_loss: 0.5574 - val_R_squared: 0.3654
# Epoch 155/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3599 - R_squared: 0.5381 - val_loss: 0.5654 - val_R_squared: 0.3506
# Epoch 156/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3614 - R_squared: 0.5226 - val_loss: 0.5747 - val_R_squared: 0.3253
# Epoch 157/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3569 - R_squared: 0.5388 - val_loss: 0.5864 - val_R_squared: 0.3095
# Epoch 158/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3739 - R_squared: 0.5134 - val_loss: 0.5712 - val_R_squared: 0.3545
# Epoch 159/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3605 - R_squared: 0.5191 - val_loss: 0.5854 - val_R_squared: 0.3171
# Epoch 160/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3576 - R_squared: 0.5099 - val_loss: 0.5928 - val_R_squared: 0.3352
# Epoch 161/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3616 - R_squared: 0.5291 - val_loss: 0.5614 - val_R_squared: 0.3085
# Epoch 162/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3563 - R_squared: 0.5185 - val_loss: 0.5621 - val_R_squared: 0.3314
# Epoch 163/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3537 - R_squared: 0.5296 - val_loss: 0.6039 - val_R_squared: 0.2781
# Epoch 164/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3635 - R_squared: 0.4922 - val_loss: 0.5837 - val_R_squared: 0.2916
# Epoch 165/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3665 - R_squared: 0.5138 - val_loss: 0.6000 - val_R_squared: 0.3183
# Epoch 166/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3585 - R_squared: 0.5361 - val_loss: 0.5605 - val_R_squared: 0.3688
# Epoch 167/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3559 - R_squared: 0.4917 - val_loss: 0.5900 - val_R_squared: 0.2756
# Epoch 168/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3449 - R_squared: 0.5326 - val_loss: 0.5745 - val_R_squared: 0.3393
# Epoch 169/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3490 - R_squared: 0.5295 - val_loss: 0.5692 - val_R_squared: 0.3445
# Epoch 170/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3478 - R_squared: 0.5369 - val_loss: 0.5610 - val_R_squared: 0.3388
# Epoch 171/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3510 - R_squared: 0.5098 - val_loss: 0.5936 - val_R_squared: 0.3074
# Epoch 172/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3458 - R_squared: 0.5433 - val_loss: 0.5734 - val_R_squared: 0.3323
# Epoch 173/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3549 - R_squared: 0.5426 - val_loss: 0.5580 - val_R_squared: 0.3543
# Epoch 174/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3565 - R_squared: 0.5301 - val_loss: 0.5566 - val_R_squared: 0.3280
# Epoch 175/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3573 - R_squared: 0.4970 - val_loss: 0.5780 - val_R_squared: 0.2946
# Epoch 176/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3435 - R_squared: 0.5313 - val_loss: 0.5710 - val_R_squared: 0.2917
# Epoch 177/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3544 - R_squared: 0.5270 - val_loss: 0.5725 - val_R_squared: 0.3470
# Epoch 178/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3472 - R_squared: 0.5392 - val_loss: 0.5582 - val_R_squared: 0.3264
# Epoch 179/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3469 - R_squared: 0.5346 - val_loss: 0.5810 - val_R_squared: 0.3179
# Epoch 180/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3454 - R_squared: 0.5408 - val_loss: 0.5702 - val_R_squared: 0.3026
# Epoch 181/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3462 - R_squared: 0.5530 - val_loss: 0.5530 - val_R_squared: 0.3218
# Epoch 182/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3388 - R_squared: 0.5477 - val_loss: 0.5553 - val_R_squared: 0.3232
# Epoch 183/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3441 - R_squared: 0.4945 - val_loss: 0.5731 - val_R_squared: 0.3357
# Epoch 184/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3389 - R_squared: 0.5634 - val_loss: 0.5667 - val_R_squared: 0.3753
# Epoch 185/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3440 - R_squared: 0.5363 - val_loss: 0.5299 - val_R_squared: 0.3911
# Epoch 186/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3432 - R_squared: 0.5337 - val_loss: 0.5529 - val_R_squared: 0.3491
# Epoch 187/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3431 - R_squared: 0.5258 - val_loss: 0.5910 - val_R_squared: 0.2717
# Epoch 188/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3461 - R_squared: 0.5552 - val_loss: 0.5493 - val_R_squared: 0.3552
# Epoch 189/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3441 - R_squared: 0.5491 - val_loss: 0.5843 - val_R_squared: 0.3069
# Epoch 190/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3446 - R_squared: 0.5081 - val_loss: 0.5534 - val_R_squared: 0.3589
# Epoch 191/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3364 - R_squared: 0.5123 - val_loss: 0.5641 - val_R_squared: 0.3265
# Epoch 192/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3416 - R_squared: 0.5351 - val_loss: 0.5547 - val_R_squared: 0.3857
# Epoch 193/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3401 - R_squared: 0.5280 - val_loss: 0.5573 - val_R_squared: 0.3459
# Epoch 194/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3375 - R_squared: 0.5576 - val_loss: 0.5769 - val_R_squared: 0.2905
# Epoch 195/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3350 - R_squared: 0.5656 - val_loss: 0.5891 - val_R_squared: 0.2608
# Epoch 196/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3387 - R_squared: 0.5508 - val_loss: 0.5381 - val_R_squared: 0.3662
# Epoch 197/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3398 - R_squared: 0.5564 - val_loss: 0.5769 - val_R_squared: 0.2833
# Epoch 198/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3356 - R_squared: 0.5567 - val_loss: 0.5677 - val_R_squared: 0.3333
# Epoch 199/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3360 - R_squared: 0.5231 - val_loss: 0.5890 - val_R_squared: 0.2793
# Epoch 200/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3342 - R_squared: 0.5535 - val_loss: 0.5551 - val_R_squared: 0.3166
# Epoch 201/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3298 - R_squared: 0.5622 - val_loss: 0.5492 - val_R_squared: 0.3714
# Epoch 202/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3320 - R_squared: 0.5236 - val_loss: 0.5308 - val_R_squared: 0.3685
# Epoch 203/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3347 - R_squared: 0.5576 - val_loss: 0.5821 - val_R_squared: 0.2623
# Epoch 204/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3300 - R_squared: 0.5583 - val_loss: 0.5510 - val_R_squared: 0.3210
# Epoch 205/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3343 - R_squared: 0.4946 - val_loss: 0.5911 - val_R_squared: 0.2867
# Epoch 206/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3360 - R_squared: 0.5560 - val_loss: 0.5580 - val_R_squared: 0.3405
# Epoch 207/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3263 - R_squared: 0.5436 - val_loss: 0.5514 - val_R_squared: 0.3555
# Epoch 208/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3287 - R_squared: 0.5409 - val_loss: 0.5540 - val_R_squared: 0.3306
# Epoch 209/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3281 - R_squared: 0.5521 - val_loss: 0.5649 - val_R_squared: 0.2947
# Epoch 210/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3330 - R_squared: 0.5589 - val_loss: 0.5435 - val_R_squared: 0.3325
# Epoch 211/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3224 - R_squared: 0.5339 - val_loss: 0.5705 - val_R_squared: 0.3096
# Epoch 212/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3281 - R_squared: 0.5288 - val_loss: 0.5821 - val_R_squared: 0.2921
# Epoch 213/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3292 - R_squared: 0.5608 - val_loss: 0.5555 - val_R_squared: 0.3507
# Epoch 214/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3370 - R_squared: 0.5518 - val_loss: 0.5362 - val_R_squared: 0.3708
# Epoch 215/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3180 - R_squared: 0.5685 - val_loss: 0.5734 - val_R_squared: 0.3359
# Epoch 216/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3295 - R_squared: 0.5597 - val_loss: 0.5422 - val_R_squared: 0.3307
# Epoch 217/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3253 - R_squared: 0.5566 - val_loss: 0.5705 - val_R_squared: 0.3295
# Epoch 218/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3237 - R_squared: 0.5574 - val_loss: 0.5794 - val_R_squared: 0.3106
# Epoch 219/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3304 - R_squared: 0.5439 - val_loss: 0.5878 - val_R_squared: 0.2610
# Epoch 220/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3284 - R_squared: 0.5499 - val_loss: 0.5491 - val_R_squared: 0.3514
# Epoch 221/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3164 - R_squared: 0.5628 - val_loss: 0.5923 - val_R_squared: 0.2701
# Epoch 222/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3209 - R_squared: 0.5653 - val_loss: 0.5332 - val_R_squared: 0.3730
# Epoch 223/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3177 - R_squared: 0.5661 - val_loss: 0.5595 - val_R_squared: 0.2894
# Epoch 224/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3200 - R_squared: 0.5574 - val_loss: 0.5737 - val_R_squared: 0.2873
# Epoch 225/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3199 - R_squared: 0.5802 - val_loss: 0.5405 - val_R_squared: 0.3439
# Epoch 226/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3202 - R_squared: 0.5859 - val_loss: 0.5972 - val_R_squared: 0.2614
# Epoch 227/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3231 - R_squared: 0.5680 - val_loss: 0.5245 - val_R_squared: 0.4133
# Epoch 228/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3227 - R_squared: 0.5649 - val_loss: 0.5501 - val_R_squared: 0.3488
# Epoch 229/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3202 - R_squared: 0.5839 - val_loss: 0.5377 - val_R_squared: 0.3971
# Epoch 230/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3216 - R_squared: 0.5854 - val_loss: 0.5357 - val_R_squared: 0.3788
# Epoch 231/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3092 - R_squared: 0.5816 - val_loss: 0.5425 - val_R_squared: 0.3159
# Epoch 232/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3163 - R_squared: 0.5689 - val_loss: 0.5636 - val_R_squared: 0.3013
# Epoch 233/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3179 - R_squared: 0.5787 - val_loss: 0.5334 - val_R_squared: 0.3922
# Epoch 234/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3137 - R_squared: 0.5744 - val_loss: 0.5487 - val_R_squared: 0.3379
# Epoch 235/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3172 - R_squared: 0.5765 - val_loss: 0.5589 - val_R_squared: 0.3670
# Epoch 236/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3150 - R_squared: 0.5816 - val_loss: 0.5317 - val_R_squared: 0.3829
# Epoch 237/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3119 - R_squared: 0.5779 - val_loss: 0.5800 - val_R_squared: 0.3064
# Epoch 238/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3062 - R_squared: 0.5890 - val_loss: 0.5402 - val_R_squared: 0.3603
# Epoch 239/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3095 - R_squared: 0.5550 - val_loss: 0.5581 - val_R_squared: 0.3543
# Epoch 240/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3124 - R_squared: 0.5467 - val_loss: 0.5433 - val_R_squared: 0.3705
# Epoch 241/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3108 - R_squared: 0.5306 - val_loss: 0.5443 - val_R_squared: 0.3536
# Epoch 242/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3107 - R_squared: 0.5653 - val_loss: 0.5489 - val_R_squared: 0.3565
# Epoch 243/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3116 - R_squared: 0.5594 - val_loss: 0.5620 - val_R_squared: 0.3368
# Epoch 244/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3204 - R_squared: 0.5537 - val_loss: 0.5519 - val_R_squared: 0.3003
# Epoch 245/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3075 - R_squared: 0.5989 - val_loss: 0.5385 - val_R_squared: 0.3750
# Epoch 246/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3149 - R_squared: 0.5590 - val_loss: 0.5479 - val_R_squared: 0.3505
# Epoch 247/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3069 - R_squared: 0.5835 - val_loss: 0.5560 - val_R_squared: 0.3420
# Epoch 248/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3133 - R_squared: 0.5924 - val_loss: 0.5530 - val_R_squared: 0.3372
# Epoch 249/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3047 - R_squared: 0.5811 - val_loss: 0.5569 - val_R_squared: 0.3189
# Epoch 250/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3063 - R_squared: 0.5797 - val_loss: 0.5538 - val_R_squared: 0.3621
# Epoch 251/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3088 - R_squared: 0.5838 - val_loss: 0.5488 - val_R_squared: 0.3967
# Epoch 252/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3079 - R_squared: 0.5658 - val_loss: 0.5440 - val_R_squared: 0.3528
# Epoch 253/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.3006 - R_squared: 0.5785 - val_loss: 0.5542 - val_R_squared: 0.3807
# Epoch 254/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3118 - R_squared: 0.5771 - val_loss: 0.5557 - val_R_squared: 0.3672
# Epoch 255/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3037 - R_squared: 0.5788 - val_loss: 0.5469 - val_R_squared: 0.3361
# Epoch 256/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3115 - R_squared: 0.5750 - val_loss: 0.5419 - val_R_squared: 0.3737
# Epoch 257/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3114 - R_squared: 0.5139 - val_loss: 0.5542 - val_R_squared: 0.3030
# Epoch 258/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.3100 - R_squared: 0.5854 - val_loss: 0.5742 - val_R_squared: 0.2865
# Epoch 259/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3023 - R_squared: 0.6057 - val_loss: 0.5606 - val_R_squared: 0.3102
# Epoch 260/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3029 - R_squared: 0.5859 - val_loss: 0.5278 - val_R_squared: 0.3572
# Epoch 261/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2981 - R_squared: 0.5845 - val_loss: 0.5268 - val_R_squared: 0.3819
# Epoch 262/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2955 - R_squared: 0.5855 - val_loss: 0.5373 - val_R_squared: 0.3314
# Epoch 263/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3073 - R_squared: 0.5692 - val_loss: 0.5304 - val_R_squared: 0.3952
# Epoch 264/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3079 - R_squared: 0.5979 - val_loss: 0.5687 - val_R_squared: 0.2703
# Epoch 265/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3149 - R_squared: 0.5644 - val_loss: 0.5168 - val_R_squared: 0.3813
# Epoch 266/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2970 - R_squared: 0.5931 - val_loss: 0.5553 - val_R_squared: 0.3416
# Epoch 267/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3044 - R_squared: 0.5831 - val_loss: 0.5826 - val_R_squared: 0.3050
# Epoch 268/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3087 - R_squared: 0.5654 - val_loss: 0.5437 - val_R_squared: 0.3495
# Epoch 269/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3072 - R_squared: 0.5888 - val_loss: 0.5319 - val_R_squared: 0.3622
# Epoch 270/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2974 - R_squared: 0.6045 - val_loss: 0.5611 - val_R_squared: 0.2870
# Epoch 271/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2956 - R_squared: 0.5994 - val_loss: 0.5301 - val_R_squared: 0.3615
# Epoch 272/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2935 - R_squared: 0.5991 - val_loss: 0.5734 - val_R_squared: 0.3145
# Epoch 273/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2987 - R_squared: 0.5913 - val_loss: 0.5535 - val_R_squared: 0.3579
# Epoch 274/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2996 - R_squared: 0.5971 - val_loss: 0.5594 - val_R_squared: 0.3403
# Epoch 275/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2909 - R_squared: 0.5864 - val_loss: 0.5646 - val_R_squared: 0.3369
# Epoch 276/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2900 - R_squared: 0.6092 - val_loss: 0.5536 - val_R_squared: 0.3121
# Epoch 277/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2924 - R_squared: 0.6042 - val_loss: 0.5642 - val_R_squared: 0.3169
# Epoch 278/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2993 - R_squared: 0.5906 - val_loss: 0.5446 - val_R_squared: 0.3406
# Epoch 279/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2953 - R_squared: 0.5936 - val_loss: 0.5602 - val_R_squared: 0.3248
# Epoch 280/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2935 - R_squared: 0.5912 - val_loss: 0.5215 - val_R_squared: 0.3727
# Epoch 281/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2901 - R_squared: 0.6069 - val_loss: 0.5487 - val_R_squared: 0.3605
# Epoch 282/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2964 - R_squared: 0.6069 - val_loss: 0.5281 - val_R_squared: 0.3667
# Epoch 283/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2988 - R_squared: 0.5939 - val_loss: 0.5520 - val_R_squared: 0.3612
# Epoch 284/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.3086 - R_squared: 0.5919 - val_loss: 0.5469 - val_R_squared: 0.3526
# Epoch 285/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2937 - R_squared: 0.6075 - val_loss: 0.5415 - val_R_squared: 0.3354
# Epoch 286/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2902 - R_squared: 0.6229 - val_loss: 0.5566 - val_R_squared: 0.3004
# Epoch 287/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2941 - R_squared: 0.5849 - val_loss: 0.5473 - val_R_squared: 0.3502
# Epoch 288/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2921 - R_squared: 0.6018 - val_loss: 0.5275 - val_R_squared: 0.3820
# Epoch 289/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2896 - R_squared: 0.6187 - val_loss: 0.5407 - val_R_squared: 0.3608
# Epoch 290/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2961 - R_squared: 0.5963 - val_loss: 0.5556 - val_R_squared: 0.3113
# Epoch 291/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2907 - R_squared: 0.5927 - val_loss: 0.5283 - val_R_squared: 0.3770
# Epoch 292/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2952 - R_squared: 0.5705 - val_loss: 0.5645 - val_R_squared: 0.3101
# Epoch 293/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2899 - R_squared: 0.6089 - val_loss: 0.5418 - val_R_squared: 0.3297
# Epoch 294/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2915 - R_squared: 0.6084 - val_loss: 0.5780 - val_R_squared: 0.2562
# Epoch 295/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2956 - R_squared: 0.5810 - val_loss: 0.5410 - val_R_squared: 0.3769
# Epoch 296/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2897 - R_squared: 0.6180 - val_loss: 0.5643 - val_R_squared: 0.3248
# Epoch 297/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2908 - R_squared: 0.5989 - val_loss: 0.5620 - val_R_squared: 0.3587
# Epoch 298/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2869 - R_squared: 0.6183 - val_loss: 0.5482 - val_R_squared: 0.3237
# Epoch 299/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2914 - R_squared: 0.5960 - val_loss: 0.5511 - val_R_squared: 0.3409
# Epoch 300/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2908 - R_squared: 0.6050 - val_loss: 0.5529 - val_R_squared: 0.3342
# Epoch 301/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2906 - R_squared: 0.5842 - val_loss: 0.5907 - val_R_squared: 0.2453
# Epoch 302/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2902 - R_squared: 0.6057 - val_loss: 0.5693 - val_R_squared: 0.3077
# Epoch 303/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2895 - R_squared: 0.6238 - val_loss: 0.5410 - val_R_squared: 0.3507
# Epoch 304/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2855 - R_squared: 0.6284 - val_loss: 0.5531 - val_R_squared: 0.3048
# Epoch 305/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2848 - R_squared: 0.6315 - val_loss: 0.5677 - val_R_squared: 0.2922
# Epoch 306/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2866 - R_squared: 0.6082 - val_loss: 0.5798 - val_R_squared: 0.2887
# Epoch 307/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2871 - R_squared: 0.5997 - val_loss: 0.5469 - val_R_squared: 0.3681
# Epoch 308/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2875 - R_squared: 0.6167 - val_loss: 0.5450 - val_R_squared: 0.3818
# Epoch 309/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2874 - R_squared: 0.5866 - val_loss: 0.5706 - val_R_squared: 0.3214
# Epoch 310/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2808 - R_squared: 0.6052 - val_loss: 0.5519 - val_R_squared: 0.3042
# Epoch 311/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2833 - R_squared: 0.5987 - val_loss: 0.5835 - val_R_squared: 0.3136
# Epoch 312/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2815 - R_squared: 0.5921 - val_loss: 0.5208 - val_R_squared: 0.3806
# Epoch 313/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2782 - R_squared: 0.5823 - val_loss: 0.5408 - val_R_squared: 0.3564
# Epoch 314/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2777 - R_squared: 0.6301 - val_loss: 0.5569 - val_R_squared: 0.3079
# Epoch 315/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2798 - R_squared: 0.6161 - val_loss: 0.5520 - val_R_squared: 0.3320
# Epoch 316/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2911 - R_squared: 0.5827 - val_loss: 0.5303 - val_R_squared: 0.3551
# Epoch 317/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2918 - R_squared: 0.5854 - val_loss: 0.5559 - val_R_squared: 0.3256
# Epoch 318/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2797 - R_squared: 0.6204 - val_loss: 0.5691 - val_R_squared: 0.2903
# Epoch 319/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2861 - R_squared: 0.5961 - val_loss: 0.5582 - val_R_squared: 0.3286
# Epoch 320/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2826 - R_squared: 0.6232 - val_loss: 0.5620 - val_R_squared: 0.3148
# Epoch 321/500
# ...
# Epoch 393/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2581 - R_squared: 0.6327 - val_loss: 0.5323 - val_R_squared: 0.3608
# Epoch 394/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2626 - R_squared: 0.6206 - val_loss: 0.5594 - val_R_squared: 0.2907
# Epoch 395/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2631 - R_squared: 0.6229 - val_loss: 0.5731 - val_R_squared: 0.2831
# Epoch 396/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2583 - R_squared: 0.6558 - val_loss: 0.5316 - val_R_squared: 0.3694
# Epoch 397/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2600 - R_squared: 0.6393 - val_loss: 0.5594 - val_R_squared: 0.3503
# Epoch 398/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2646 - R_squared: 0.6434 - val_loss: 0.5499 - val_R_squared: 0.3306
# Epoch 399/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2630 - R_squared: 0.6413 - val_loss: 0.5369 - val_R_squared: 0.3756
# Epoch 400/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2616 - R_squared: 0.6161 - val_loss: 0.5479 - val_R_squared: 0.3498
# Epoch 401/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2613 - R_squared: 0.6133 - val_loss: 0.5326 - val_R_squared: 0.3488
# Epoch 402/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2583 - R_squared: 0.6537 - val_loss: 0.5301 - val_R_squared: 0.3275
# Epoch 403/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2593 - R_squared: 0.6323 - val_loss: 0.5467 - val_R_squared: 0.3191
# Epoch 404/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2559 - R_squared: 0.6252 - val_loss: 0.5552 - val_R_squared: 0.3244
# Epoch 405/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2614 - R_squared: 0.6299 - val_loss: 0.5512 - val_R_squared: 0.3393
# Epoch 406/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2627 - R_squared: 0.6244 - val_loss: 0.5557 - val_R_squared: 0.3390
# Epoch 407/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2605 - R_squared: 0.6236 - val_loss: 0.5251 - val_R_squared: 0.3645
# Epoch 408/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2564 - R_squared: 0.6083 - val_loss: 0.5403 - val_R_squared: 0.3463
# Epoch 409/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2582 - R_squared: 0.6337 - val_loss: 0.5510 - val_R_squared: 0.3237
# Epoch 410/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2522 - R_squared: 0.6394 - val_loss: 0.5536 - val_R_squared: 0.3521
# Epoch 411/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2611 - R_squared: 0.6482 - val_loss: 0.5539 - val_R_squared: 0.3257
# Epoch 412/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2638 - R_squared: 0.6342 - val_loss: 0.5556 - val_R_squared: 0.3504
# Epoch 413/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2585 - R_squared: 0.6448 - val_loss: 0.5607 - val_R_squared: 0.3539
# Epoch 414/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2577 - R_squared: 0.6061 - val_loss: 0.5437 - val_R_squared: 0.3493
# Epoch 415/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2621 - R_squared: 0.6001 - val_loss: 0.5303 - val_R_squared: 0.3523
# Epoch 416/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2533 - R_squared: 0.6194 - val_loss: 0.5346 - val_R_squared: 0.3360
# Epoch 417/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2572 - R_squared: 0.6582 - val_loss: 0.5476 - val_R_squared: 0.3315
# Epoch 418/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2559 - R_squared: 0.6277 - val_loss: 0.5522 - val_R_squared: 0.2885
# Epoch 419/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2517 - R_squared: 0.6444 - val_loss: 0.5507 - val_R_squared: 0.3386
# Epoch 420/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2524 - R_squared: 0.6580 - val_loss: 0.5449 - val_R_squared: 0.3201
# Epoch 421/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2573 - R_squared: 0.6234 - val_loss: 0.5480 - val_R_squared: 0.3086
# Epoch 422/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2569 - R_squared: 0.6253 - val_loss: 0.5541 - val_R_squared: 0.3057
# Epoch 423/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2561 - R_squared: 0.6419 - val_loss: 0.5356 - val_R_squared: 0.3327
# Epoch 424/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2516 - R_squared: 0.6408 - val_loss: 0.5264 - val_R_squared: 0.3616
# Epoch 425/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2607 - R_squared: 0.6405 - val_loss: 0.5469 - val_R_squared: 0.3083
# Epoch 426/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2514 - R_squared: 0.6525 - val_loss: 0.5504 - val_R_squared: 0.3348
# Epoch 427/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2560 - R_squared: 0.6388 - val_loss: 0.5466 - val_R_squared: 0.3326
# Epoch 428/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2555 - R_squared: 0.6477 - val_loss: 0.5315 - val_R_squared: 0.3641
# Epoch 429/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2478 - R_squared: 0.6486 - val_loss: 0.5447 - val_R_squared: 0.3802
# Epoch 430/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2588 - R_squared: 0.6328 - val_loss: 0.5499 - val_R_squared: 0.3501
# Epoch 431/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2540 - R_squared: 0.6576 - val_loss: 0.5165 - val_R_squared: 0.3689
# Epoch 432/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2559 - R_squared: 0.6636 - val_loss: 0.5490 - val_R_squared: 0.3529
# Epoch 433/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2477 - R_squared: 0.6609 - val_loss: 0.5237 - val_R_squared: 0.3644
# Epoch 434/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2518 - R_squared: 0.6220 - val_loss: 0.5240 - val_R_squared: 0.3676
# Epoch 435/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2523 - R_squared: 0.6236 - val_loss: 0.5437 - val_R_squared: 0.3204
# Epoch 436/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2564 - R_squared: 0.6472 - val_loss: 0.5296 - val_R_squared: 0.3744
# Epoch 437/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2515 - R_squared: 0.6684 - val_loss: 0.5611 - val_R_squared: 0.3210
# Epoch 438/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2502 - R_squared: 0.6388 - val_loss: 0.5731 - val_R_squared: 0.2852
# Epoch 439/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2522 - R_squared: 0.6357 - val_loss: 0.5431 - val_R_squared: 0.3332
# Epoch 440/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2522 - R_squared: 0.6385 - val_loss: 0.5718 - val_R_squared: 0.2806
# Epoch 441/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2541 - R_squared: 0.6324 - val_loss: 0.5686 - val_R_squared: 0.2961
# Epoch 442/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2468 - R_squared: 0.6657 - val_loss: 0.5667 - val_R_squared: 0.3052
# Epoch 443/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2483 - R_squared: 0.6401 - val_loss: 0.5278 - val_R_squared: 0.3474
# Epoch 444/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2517 - R_squared: 0.6577 - val_loss: 0.5594 - val_R_squared: 0.3067
# Epoch 445/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2511 - R_squared: 0.6411 - val_loss: 0.5384 - val_R_squared: 0.3656
# Epoch 446/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2491 - R_squared: 0.6383 - val_loss: 0.5205 - val_R_squared: 0.3710
# Epoch 447/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2502 - R_squared: 0.6567 - val_loss: 0.5313 - val_R_squared: 0.3671
# Epoch 448/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2578 - R_squared: 0.6455 - val_loss: 0.5456 - val_R_squared: 0.3390
# Epoch 449/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2494 - R_squared: 0.6396 - val_loss: 0.5382 - val_R_squared: 0.3577
# Epoch 450/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2515 - R_squared: 0.6656 - val_loss: 0.5210 - val_R_squared: 0.3837
# Epoch 451/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2455 - R_squared: 0.6539 - val_loss: 0.5543 - val_R_squared: 0.3000
# Epoch 452/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2529 - R_squared: 0.6536 - val_loss: 0.5202 - val_R_squared: 0.3709
# Epoch 453/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2492 - R_squared: 0.6487 - val_loss: 0.5355 - val_R_squared: 0.3463
# Epoch 454/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2476 - R_squared: 0.6527 - val_loss: 0.5451 - val_R_squared: 0.3412
# Epoch 455/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2498 - R_squared: 0.6582 - val_loss: 0.5282 - val_R_squared: 0.3674
# Epoch 456/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2505 - R_squared: 0.6670 - val_loss: 0.5372 - val_R_squared: 0.3762
# Epoch 457/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2516 - R_squared: 0.6220 - val_loss: 0.5418 - val_R_squared: 0.3263
# Epoch 458/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2524 - R_squared: 0.6609 - val_loss: 0.5461 - val_R_squared: 0.3216
# Epoch 459/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2526 - R_squared: 0.6365 - val_loss: 0.5463 - val_R_squared: 0.3324
# Epoch 460/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2495 - R_squared: 0.6510 - val_loss: 0.5467 - val_R_squared: 0.3349
# Epoch 461/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2392 - R_squared: 0.6575 - val_loss: 0.5455 - val_R_squared: 0.3403
# Epoch 462/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2558 - R_squared: 0.6508 - val_loss: 0.5701 - val_R_squared: 0.2969
# Epoch 463/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2437 - R_squared: 0.6319 - val_loss: 0.5289 - val_R_squared: 0.3734
# Epoch 464/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2479 - R_squared: 0.6496 - val_loss: 0.5660 - val_R_squared: 0.2973
# Epoch 465/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2535 - R_squared: 0.6536 - val_loss: 0.5411 - val_R_squared: 0.3411
# Epoch 466/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2493 - R_squared: 0.6456 - val_loss: 0.5458 - val_R_squared: 0.3140
# Epoch 467/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2454 - R_squared: 0.6491 - val_loss: 0.5315 - val_R_squared: 0.3637
# Epoch 468/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2444 - R_squared: 0.6530 - val_loss: 0.5532 - val_R_squared: 0.3084
# Epoch 469/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2421 - R_squared: 0.6668 - val_loss: 0.5157 - val_R_squared: 0.3430
# Epoch 470/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2485 - R_squared: 0.6452 - val_loss: 0.5219 - val_R_squared: 0.3621
# Epoch 471/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2440 - R_squared: 0.6748 - val_loss: 0.5656 - val_R_squared: 0.3058
# Epoch 472/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2451 - R_squared: 0.6450 - val_loss: 0.5525 - val_R_squared: 0.3192
# Epoch 473/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2452 - R_squared: 0.6502 - val_loss: 0.5373 - val_R_squared: 0.3444
# Epoch 474/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2487 - R_squared: 0.6609 - val_loss: 0.5497 - val_R_squared: 0.3371
# Epoch 475/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2471 - R_squared: 0.6595 - val_loss: 0.5567 - val_R_squared: 0.3264
# Epoch 476/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2486 - R_squared: 0.6489 - val_loss: 0.5544 - val_R_squared: 0.3023
# Epoch 477/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2418 - R_squared: 0.6799 - val_loss: 0.5623 - val_R_squared: 0.3007
# Epoch 478/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2436 - R_squared: 0.6389 - val_loss: 0.5459 - val_R_squared: 0.3309
# Epoch 479/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2413 - R_squared: 0.6732 - val_loss: 0.5341 - val_R_squared: 0.3388
# Epoch 480/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2543 - R_squared: 0.6495 - val_loss: 0.5542 - val_R_squared: 0.3188
# Epoch 481/500
# 494/494 [==============================] - 1s 2ms/step - loss: 0.2504 - R_squared: 0.6417 - val_loss: 0.5653 - val_R_squared: 0.3233
# Epoch 482/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2393 - R_squared: 0.6672 - val_loss: 0.5620 - val_R_squared: 0.3239
# Epoch 483/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2414 - R_squared: 0.6674 - val_loss: 0.5437 - val_R_squared: 0.3313
# Epoch 484/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2447 - R_squared: 0.6451 - val_loss: 0.5653 - val_R_squared: 0.2807
# Epoch 485/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2510 - R_squared: 0.6589 - val_loss: 0.5309 - val_R_squared: 0.3368
# Epoch 486/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2417 - R_squared: 0.6348 - val_loss: 0.5245 - val_R_squared: 0.3853
# Epoch 487/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2415 - R_squared: 0.6597 - val_loss: 0.5499 - val_R_squared: 0.3332
# Epoch 488/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2407 - R_squared: 0.6617 - val_loss: 0.5262 - val_R_squared: 0.3623
# Epoch 489/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2398 - R_squared: 0.6634 - val_loss: 0.5295 - val_R_squared: 0.3948
# Epoch 490/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2396 - R_squared: 0.6660 - val_loss: 0.5524 - val_R_squared: 0.3365
# Epoch 491/500
# 494/494 [==============================] - 2s 3ms/step - loss: 0.2449 - R_squared: 0.6454 - val_loss: 0.5377 - val_R_squared: 0.3417
# Epoch 492/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2397 - R_squared: 0.6491 - val_loss: 0.5498 - val_R_squared: 0.3351
# Epoch 493/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2442 - R_squared: 0.6345 - val_loss: 0.5403 - val_R_squared: 0.3209
# Epoch 494/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2399 - R_squared: 0.6546 - val_loss: 0.5498 - val_R_squared: 0.3525
# Epoch 495/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2432 - R_squared: 0.6692 - val_loss: 0.5504 - val_R_squared: 0.3320
# Epoch 496/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2466 - R_squared: 0.6443 - val_loss: 0.5292 - val_R_squared: 0.3474
# Epoch 497/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2345 - R_squared: 0.6717 - val_loss: 0.5506 - val_R_squared: 0.3314
# Epoch 498/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2356 - R_squared: 0.6799 - val_loss: 0.5969 - val_R_squared: 0.2337
# Epoch 499/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2378 - R_squared: 0.6625 - val_loss: 0.5609 - val_R_squared: 0.3064
# Epoch 500/500
# 494/494 [==============================] - 1s 3ms/step - loss: 0.2359 - R_squared: 0.6814 - val_loss: 0.5584 - val_R_squared: 0.3152

# %%
hist = NN_model.history

# %%
hist.history.keys()
# Out:
# dict_keys(['loss', 'R_squared', 'val_loss', 'val_R_squared'])

# %%
plt.plot(range(len(hist.history['R_squared'])), hist.history['R_squared'], label = 'training')
plt.plot(range(len(hist.history['val_R_squared'])), hist.history['val_R_squared'], label = 'validation')
plt.legend(loc='best')
plt.xlabel('Epochs')
plt.ylabel('R2 score')
# Out:
# Text(0, 0.5, 'R2 score')

# %% [markdown]
# **The neural networks although improves the training R2 score over epochs, fails to improve the R2 score on test data.**

# %% [markdown]
# # **CONCLUSION**

# %% [markdown]
# 1. **The temperature/ humidity features showed little to no pearson correlation w.r.t target variable (<1%), although being highly correlated within themselves.**
#
# 2. **The time zone of the day plays an important role in deciding power consumption of appliances.**
#
# 3. **The best Algorithm to use for this dataset is Extra Trees Regressor (tree based algorithm)**
#
# 4. **PCA helped us to reduce our feature set dimension considerably without affecting performance of our models significantly.**
#
# 5. **The untuned model was able to explain 64.5% of variance (R2 score = 0.645) on test set, while the tuned model was able to explain 64.9% of variance (R2 score = 0.649) on test set which is a tiny improvement of < 1 %**
#
# 6. **The least RMSE score on test data set is found to be around 0.6 by Extra trees regressor model, which is considerably good compared to other models.**
#
# 7. **Tree based models are by far the best model while dealing with data set that has most of its features having no linear correlation with target variable. For similar reasons, linear models such as linear regression, Ridge and Lasso perform the worst.**
